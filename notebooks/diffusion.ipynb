# %%
import MDAnalysis as mda
import MDAnalysis.analysis.msd as msd
from pathlib import Path
import numpy as np
from scipy.stats import linregress
import matplotlib.pyplot as plt

import sys
sys.path.append("/home/boittier/Documents/phd/water-knn")
from analysis.md import *

# %%
base = Path("/home/boittier/pcbach/waterlj/ccsdt-1-r3/")

u = load_unwrapped_dcd(base)
MSD = calc_msd(u)

# %%
results = fit_D_from_MSD(MSD)

# %%
plot_self_diffusion(results)
